# %%
import os
def delete_all_files_in_folder(folder_path):
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.unlink(file_path)
            elif os.path.isdir(file_path):
                delete_all_files_in_folder(file_path)
        except Exception as e:
            print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
from collections import OrderedDict
from multiprocessing import Pool
from cutting_polygon import *
from shapely.geometry import Polygon
import os
import numpy as np
import json
# number of LabelMe2YOLO multiprocessing threads
NUM_THREADS = max(1, os.cpu_count() - 1)
FACENAME_LIST = ["negx", "posx", "negy","posy", "negz", "posz"]
FACEMAP_DICT = {"negx":[0,1,1,2],"posx":[2,3,1,2],"negy":[1,2,0,1],"posy":[1,2,2,3],"negz":[3,4,1,2],"posz":[1,2,1,2],}

def get_label_id_map(json_dir: str):
    '''Get label id map from json files in json_dir'''
    label_set = set()

    for file_name in os.listdir(json_dir):
        if file_name.endswith("json"):
            json_path = os.path.join(json_dir, file_name)
            data = json.load(open(json_path))
            for shape in data["annotations"]:
                label_set.add(shape["name"])
    
    label_list = []
    for label_id, label in [(label, label_id) for label_id, label in enumerate(label_set)]: 
        print(label_id, label)
        label_list.append((label_id+"_hole", label+len(label_set)))
        label_list.append((label_id, label))

    return OrderedDict(label_list)


class Darwin2YOLO(object):
    '''Darwin to YOLO format converter'''
    def __init__(self, json_dir, output_format, label_list):
        self._json_dir = json_dir
        self._output_format = output_format
        self._label_list = label_list

        if label_list:
            self._label_id_map = {label: label_id
                                  for label_id, label in enumerate(label_list)}
            #print(self._label_id_map)
        else:
            self._label_id_map = get_label_id_map(self._json_dir)
            print((self._label_id_map))
            self._label_list = [label for label in self._label_id_map.keys()]
            print((self._label_list))
            
    def convert(self):
        json_names = [file_name for file_name in os.listdir(self._json_dir)
                      if os.path.isfile(os.path.join(self._json_dir, file_name)) and
                      file_name.endswith('.json')]
        self.output_path = os.path.join(self._json_dir + '/output/')
        if os.path.exists(self.output_path):
            delete_all_files_in_folder(self.output_path)
        else:
            os.makedirs(self.output_path)

        # convert labelme object to yolo format object, and save them to files
        # also get image from labelme json file and save them under images folder
        pool = Pool(NUM_THREADS)

        for json_name in json_names:
            self.covert_json_to_text(self.output_path, json_name)
            #pool.apply_async(self.covert_json_to_text,
                                #args=(output_path, json_name))
        pool.close()
        pool.join()

        
    def covert_json_to_text(self, target_dir, json_name):
        json_path = os.path.join(self._json_dir, json_name)
        json_data = json.load(open(json_path))

        print('Converting %s for %s ...' %
              (json_name, target_dir.replace('/', '')))

        yolo_obj_dict = self._get_yolo_object_list(json_data)
        
        for facename in FACENAME_LIST:
            x = yolo_obj_dict.get(facename, None)
            #print(f"x = {x}")
            if x is not None:
                save_yolo_label(json_name[:-5] +"_"+ facename+".json",
                                self.output_path,
                                x)
        
    def _get_yolo_object_list(self, json_data):
        
        # initialize dictionary
        dict_yolo_obj_list = {}
        
        # iterating through the elements of list
        for i in FACENAME_LIST:
            dict_yolo_obj_list[i] = []

        #img_h, img_w, _ = cv2.imread(img_path).shape
        img_w = int(json_data["item"]["slots"][0]["width"])
        img_h = int(json_data["item"]["slots"][0]["height"])

        #for each object annotated
        for shape in json_data["annotations"]:

            yolo_obj_list = self._get_other_shape_yolo_object(
                shape, img_h, img_w)
            
            #for each polygon i: (each object can have more than 1 polygon)
            #   yolo_obj_list[i][0] = [class,points]
            #   yolo_obj_list[i][1] = [face]
            #   yolo_obj_list[i][0][0] = [class]
            #   yolo_obj_list[i][0][1] = [points]

            poly_list = [Polygon(yolo_obj_list[i][0][1]) for i in range(len(yolo_obj_list))]

            #print(f"len(yolo_obj_list) = {len(yolo_obj_list)}")
            #print(f"len(poly_list) = {len(poly_list)}")
            #print(f"")
            #print(type(yolo_obj_list[0][0]))
            #for yolo_obj, cubemap_faces in yolo_obj_list:
            for i in range(len(yolo_obj_list)):
                yolo_obj, cubemap_faces = yolo_obj_list[i]

                area_superposition_count = 0

                for polyb in poly_list:
                    if poly_list[i] != polyb:
                        if polyb.contains(poly_list[i]):
                            area_superposition_count+=1
                #print(f"area_superposition_count = {area_superposition_count}")

                if area_superposition_count%2==1:
                    yolo_obj[0] += len(self._label_list)//2
                    #print(f"yolo_obj_list[i][0][1] = {yolo_obj_list[i][0][1]}")
                    #print(f"is a hole")
                    #print(f"----------------------------------------------------")

                for cubemap_face in cubemap_faces:
                    x = dict_yolo_obj_list.get(cubemap_face, None)
                    if x is not None:
                        minX, maxX, minY, maxY = FACEMAP_DICT.get(cubemap_face,None)
                        
                        #TODO lembrar de tirar esse if depois
                        if cubemap_face == "NADA":
                            print(f"minY = {minY}")
                            print(f"maxY = {maxY}")
                            print(f"minX = {minX}")
                            print(f"maxX = {maxX}")
                            print(f"uncut polygon = {yolo_obj[1]}")
                        resulting_polygons = cut_polygon_between_2_horizontal_line(yolo_obj[1], minY, maxY)
                        resulting_polygons = cut_polygon_between_2_vertical_line(resulting_polygons, minX, maxX)
                        if cubemap_face == "NADA":
                            print(f"resulting_polygons = {resulting_polygons}")
                            print("")
                        if len(resulting_polygons) > 0:
                            x.append([yolo_obj[0]] + resulting_polygons)
                    else:
                        print("x ta sendo None, isso n devia estar acontecendo")

        return dict_yolo_obj_list
    
    def _get_other_shape_yolo_object(self, shape, img_h, img_w):

        yolo_obj_list = []        
        #point_list = shape["polygon"]["paths"][0]
        polygon_list = shape["polygon"]["paths"]

        for point_list in polygon_list:
            points = np.zeros((len(point_list),2))

            #points[::2] = [(float(point[0]) / img_w) if point[0]<=img_w else 1 for point in point_list]
            # limit of points are img_w and img_h
            #points[::2] = [1 if float(point["x"]) > img_w else 
            #               (0 if float(point["x"]) < 0 else 
            #                (float(point["x"]) / img_w)) for point in point_list]
            
            #points[1::2] = [(float(point[1]) / img_h) if point[1]<=img_h else 1 for point in point_list]
            #points[1::2] = [1 if float(point["y"]) > img_h else 
            #               (0 if float(point["y"]) < 0 else 
            #                (float(point["y"]) / img_h)) for point in point_list]

            points[:] = [[point_list[i]["x"]/ img_w, point_list[i]["y"]/ img_h] for i in range(len(point_list))]
            #points[::2] = points[::2]*4
            #points[1::2] = points[1::2]*3
            points.clip(0,1)
            #print(f"points = {points}")
            points = points * (4,3)
            cubemap_faces = self.get_cubemaps_faces(points[:, 0], points[:, 1])

            #print(f"shape['label'] = {shape['label']}")
            #print(f"_label_id_map = {self._label_id_map}")

            shape_label = shape.get('name',-1)
            #print(f"shape_label = {shape_label}")
            if shape_label in self._label_id_map:
                label_id = self._label_id_map[shape_label]
                #print(f"label_id = {label_id}")
                #print(f"")
            else:
                print(f"label {shape['name']} not in {self._label_list}")
                return -1
            #print(points)
            yolo_obj_list.append(([label_id, points.tolist()], cubemap_faces))
        return yolo_obj_list
    
    def get_cubemaps_faces(self, points_x, points_y):
        cubemaps_faces = []
        for (x,y) in zip(points_x, points_y):
            if x<=1:
                cubemaps_faces.append("negx") if "negx" not in cubemaps_faces else cubemaps_faces
            if x>=1 and x<=2:
                if y<=1:
                    cubemaps_faces.append("negy") if "negy" not in cubemaps_faces else cubemaps_faces
                if y>=1 and y<=2:
                    cubemaps_faces.append("posz")  if "posz" not in cubemaps_faces else cubemaps_faces
                if y>=2:
                    cubemaps_faces.append("posy") if "posy" not in cubemaps_faces else cubemaps_faces
            if x>=2 and x<=3:
                cubemaps_faces.append("posx") if "posx" not in cubemaps_faces else cubemaps_faces
            if x>=3:
                cubemaps_faces.append("negz") if "negz" not in cubemaps_faces else cubemaps_faces
            
        return cubemaps_faces
    
def save_yolo_label(json_name, output_path, yolo_obj_list):
    '''Save yolo label to txt file'''
    txt_path = os.path.join(output_path,
                            "cubemap_"+json_name.replace(".json", ".txt"))
    face = json_name[-9:-5]
    
    with open(txt_path, "w+") as f:
        for yolo_obj in yolo_obj_list:
            #print(f"yolo_obj ={yolo_obj}")
            label = yolo_obj[0]
            points = custom_modulo(flatten(yolo_obj[1:]), face)
            points = [str(item) for item in points]
            yolo_obj_line = f"{label} {' '.join(points)}\n"
            f.write(yolo_obj_line)

def custom_modulo(points, face):
    return_list = np.array(points)
    return_list[::2]=return_list[::2]-(FACEMAP_DICT.get(face,0)[0])
    return_list[1::2]=return_list[1::2]-(FACEMAP_DICT.get(face,0)[2])
    return return_list.tolist()

def flatten(l):
    return [item for sublist in l for item in sublist]

# %%
convertor = Darwin2YOLO(json_dir="SISTEMAS_UFF/corrosion-v4/", output_format="polygon",label_list=None)
convertor.convert()
# Out:
# Corrosão 0
# OrderedDict([('Corrosão_hole', 1), ('Corrosão', 0)])
# ['Corrosão_hole', 'Corrosão']
# Converting P74_01b88e07cc3ff7126288fc499d9c4ba4.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_db49b901d10c04bef7fa1a1fd0448dac.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_9c1a613db60312d3f1ba7b5c36044c94.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_fcf1ef699272142e54979be634513d81.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_764b2ec5a4038b7a934cc54be82aa580.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_8f542b4547d7e7034bda8ff839be3445.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_35182ee3e16b64dea83dda27a2951ccc.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_585e157b95823096d8a3415f64ab02a6.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_71dc91a34f2deb552cf7eaa1e4484975.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_81bc6236508f38d6c14ed32a6133c32d.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_0b27449efda1cc4299bdd92090921266.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_9cf893af60fb137ed763c2d1a9af430e.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ef7d57c1341333b4fc151b30ccff0892.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_4c2ac3a5081e3a58c0b148d43f4fc3da.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_4afe27d888110d9e53cf8b9e1e052185.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_3b3103008ba80b7177f24158ac0e14f3.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_6a93230535f3f342bb6ef027cbdbedf5.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_e3e3ece3e67074ffa69a3e741dd5997e.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_85ae772d93db540c64e40c4c853a9dad.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_1acf57c1578d6e9b90e3051c7f267120.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_2cc751e5b3795aecda125d97a259c894.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_577c9b154c95a6cf13d463ccc5c0e919.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_6243661e191e7a2490cd55da901b5fcb.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_c7d9f502deadf95aa72878104c2a406e.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_7411540e1f8917b0cdf109b35aa020a6.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_05e412fcb10130ef7a64201656bf52aa.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_541ae478b65d3d5598213913edec5dc7.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_815e6a8d8983be0d4020b95c1ed5478c.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_1ec1458224a2832e9c2266b576bf86dd.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ecb640fc7c4fba7d21d206792722d283.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_4425f83256bf7d5be9b5b6eecdbb6de1.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_6a5c7b6b8c46d2f7b449de517c31809a.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_497fe6f6ade7659f9b78ec56610f54b1.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_29090ed6e8e1f894f6dbdd4161aed6db.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_22ee2c1dab290313e8a41f6f0161ede7.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_8b389e67444d6566c9b0281463381ba6.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_fd3e0618df9fb6554356c14b6d9096eb.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_90f033ff045af4d1f273cca23d4092ed.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_c2a653d9f6777899ef8c2cb5d057874f.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_7bcdfe585c4368ed446026227d87aa97.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_91c659f122dbffd368c780067bb87668.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_b34372f7fd34161a58d9f2a1a8f7cec3.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_7afdffca10bc9bc22bce7e2d33ac3a4d.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_63487d1f27267d9dc203362807e73e18.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_4443304d42b15a89f5fc83a3ae90eb6d.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_37031a394df6ffc0b0c6e9d657945d77.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_34a3386b52ee44171705c3d73b890689.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_19d196c15c2bbe8ceec736df7505bf12.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_4fa44c396fd4c1758d866db06f53e5e6.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ab9d5dddabe106d9100cb4562980cdb4.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ed7435d1327844d82985959cfc6ab7b8.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_d010218000bd9d155c0f8ca82bd91410.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_370743d51bdf896e77a61002537d287e.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_7b406175f403254679bf2f0e6fba873d.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_89a3dab63af2ed3f5ace36c40e525d08.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_667d90961a0a239a4ffd476ec7064626.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_47173ee8180cdf15ecf3de611ba27dba.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_def8fb1744221b2ee2bc747afe731fc8.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_23804c4c3a3746cee6821bd517eeddeb.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_a36a1a90b0a277fdfa89b3e7d934e70f.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_cba5dec198399495568573125175ee6f.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_c4ebee03f37f9d99d9be1d420bbf8025.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_7a9815f38bea8e647081ba3a6159bd6c.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_04c295e8c6b8dca9a4314bb3cf953434.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_5b2d0c4854a5cc37eca2011944d9e1ee.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_cc278124443f75a50175bc6c7c9cb5b8.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_c69c7c2acffc0afcee64f73cb1358c2f.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_c2c111d141f7f07f6455c3fe50b704ef.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_d074517fdca031e275c16683de5bf680.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_61862f5acb73501712bd96e769e8dde7.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_496b68455c289f8859cd228edd0f5b90.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_1a1ae932e2cabb0ad931f4bb00c94cd5.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_5b66826d022527c702744d88a5f5d3c2.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_0d60988e43ca8e5e93f0de4de1fea501.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_d9e5338c7331d756d4626f1f5bd5e1d4.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_3da08ca772884dd8672b3033d8b5262a.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_e78aecf9b104474f1aa16a76b98702b1.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_bdeacca03e85ffdb0ed1b7d7429002d0.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_d22f19724668d680f76b68f178a7724d.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_9941c8f5f70d8f8a8e807eac7bfbc2fa.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_077d8651cb34c55869b48c0781e0a779.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_888eeb1e10318339d75bea5f7b1b0ded.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_b157cd6a5d921572e4f8d4826fd4400f.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ab75268dc401097387c01f6a1dc67da1.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_4b34fc9336f6e98dfb3384576688df80.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_280843655714c8a052cc0e99faad2d8f.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_a03fecc65f3b31ee351726e2cd002290.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_77ed0aaa80740f0902d61f0c43d42062.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_41a5ed8e08e592aec57ae7c19b4d831a.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_234eba2b102514f9085b869cf832894f.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_a5068fab24fd601d8f35b12fa2b3ad34.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_60e7f7bbe4021bd5e092ba94d6d502b7.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_1a7f8b6eb496506c2699e0aea10c32e4.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_a3686235d926a37ae214fd43c25bb0c4.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_5378a14b3526d5f3b5bfbfcb2cea4b1e.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_4d866af3fb911815b086aa6f35848dab.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_99d653c84e0c0e9eba36c59f2ac3dde2.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ebef90aff2bf26ef35aaee7f6bbe0764.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_3c9925b681cd5422efacb8f70c596f70.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_fb48bf8c7a98b06384f1f93fcf027adb.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_e637b1d347f0fc56069edb8ab8558b9d.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_d8d573bd2ea95712bf5af692d98a85f2.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_f3dc852a78316e3e87221d4992ee5d3f.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_56e3227caba2071434d6ae9d31af6ce2.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_00c590f7cd08c56d9d73390dd2a085b5.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_b99e6583dbfb1c671040344b920938bd.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_3880dbc19bdd9362d4d3e80b2a008148.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_617924833916c9c94f198288f50ef4ee.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_a8a0ef7abaa27f93b8064b7a548088ca.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_bf0f0b46770c4a5b82c14b1f696eb6bf.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_6d6e5b2c1edcb647e3d71f27ac89c141.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_e08f08fc0d77e6f74ba1d60253c632f9.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_c9d7aba99a0c6a8449b99b84bc20e551.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_7f2462e170f7be128ec08094bc8251db.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_644bd8eb5621a9f448ee3aa150f1c690.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_9c191d7d516dca428274d484b3780da5.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_2ebe7ccc388a016ecbb8d63660a5b983.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_1d9995cc2666bb90e6b568c05cf01ced.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_92a0e6212bd505fe452d59094bdb7654.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_07e44027027c81532949edaf4cf30f2a.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_b7238f29e1318e410d6498d1b40cd7be.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ce4bbd644365bcf69e85fb1f22dc5813.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_adbe0887b52bcfcbd42ab6c65d31741b.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_750d4e57f40517de994d1c3f138edf93.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_333103db8ae69121a63b2939977e5fe7.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_0836793e6fd07cd1fbec1520ad042936.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_391ac6e4cd5f1b498a0caae90d2a5abf.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_edab66617be194a03baf4144899f30ef.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_d31875d361c6cbcfbce07cf0ad147d8b.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_cc39a7d67c298a3ce2a2e077cb322bf3.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_8c3a0c302203a871a1274f122b12c75b.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_0030931c0e3aaaa3a10a9e0f63195eb2.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_7d118f30edd3ce3e3dc9cb902a6d1806.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_dd3a969bbd7eecad19d3b8c4e1ac37bb.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_4989c69435e859d005066ae140348375.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_2543512a676d21261b03f0a85dca05ff.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_307cad955e811287c28e79c0d1495cef.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_df1ea7387710ea3982cef1c05cfbcfac.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_9c005458862954d3ef9321003ea602ec.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_f81dbf357b066d0d51a05da35e32d1ed.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ecfd0ce4391c33c8f8b68e45b4e4a1c2.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_77d26c2018b5bf9014df01af7167eed4.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_a34a2d6e90d8044a260bb5376ba3b3f9.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ddd8ddf3f7a08c8ee50151a50943ee23.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ff772330f4d621f8d9338d1007f61ce2.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_3b0706f904c269c72b8f48bfa1fbc72c.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ee1a21d60b93b34eb51e4c479ca96113.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_82c1b02b61c997959897b96f8ba7eaa1.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_29ff1f33691ce3754b3e7b09f2281a06.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_5b07fb3c6d78f4716dd295e8833ac8d9.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_395bd48ea4c16c94842b4d508921f2df.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_7479f59cc0e5826649df2dd87911d7b1.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_4920ea9c80e70b9262fd0ae106fc24a6.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ec99c16b80e8b45c437762f7c72bdd9f.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_65c9a8a517889b0f2505f2523e01a1be.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_2397db1650dc33e2d472a1fbb3aa411a.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_c8334da33595a38517f5062f3166ae60.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_a09c6d81a53961bb327960163dada43a.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_12bba01785a2882f09722e7e46260bae.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_5f07b63ef3b23838a68437653ba5c417.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_82e25a1f5660caa3e7ca350fe2a0a680.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_74f147359e6336e8d053c3e187809f2a.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_a9cc4f856fac2efaa9caafa146bca401.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_0dc775b234c73426b0eddc3204c7da3c.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_b16b0579932eb15529ce63a4ebc015dd.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_b9906893446660123ab2e333f4975f97.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_d112b3a5ae3a56b1b1c33e05ba8156d8.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_c650eaa4f95b35c421f969046c676e51.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_e353aa9998cfa6f11bafec3ba2048708.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_5d1a4ffbcb8b43d55bb8af35519d6c41.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_5c7c9280bbe1560f900850f28490d7dd.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ff3754b0769f3e87637ab63033d2ab90.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_ec7a6260a49e24956626880bce5d1c31.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_08138abfa23b421ccde6d69d26e07c01.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_3c378224dbf46c8375699cedad91c3fc.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_cb7c88ab2075f0ff3954f3c833f53625.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_f9a59a1270efba30adedc87b7ffcb259.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_466928b033b869299ec80f1d25ea0e92.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_09a6e1f9892765e8c5ee91232770c2a0.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_550ebbd6e6950901ed4724a342e01b30.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_f1329dcefa000227356ce9b7f831bcd1.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_e2d1c687e01c73ccf70ab23af0312d84.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_a6063edd53bd1f1bd9051ec16bf7c965.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_7ddf1d3a5f8a38b178a352fb2bcdcdc5.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_cdc4e49eb39b12e75404f2b6ca9783a9.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_51f0eacaafd3cbf41cac3ea83348fe7b.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_7438f04079359d40c8ff5be0f33ab427.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_fad0abce514a21e6bed82176dce7523c.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_53026b3600c59ad8d11e1e04e9d93af6.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_d066e4d6c5b78b22115d73bcfe7866dd.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_e72c6894a2f8db9ad371dd85585e7fea.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_3a92aa48c883a40f0ff44646fab82234.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_e166eb37446cd140929271845396d86e.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_a38108830dd4372900c7a6f3281cc63b.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_6d9b9023c289c38dd88002e146820966.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_061c26f540defe6042ea1da541f67957.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_4c77848b1a7305097a6775016f6d0945.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_644a829312a12b37900c2392d8cb75d4.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_e06b01cc736bee3fa542724edb554175.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_a538c9c9da998f2509d77e70bb531e7b.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_f79257d49299ce2eb46bc0588a3e795c.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_8fcd9fa9885e19da881ed7e82c602d3e.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_37531c118855f42843521926854ad7cf.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_e9a75459d6ecc78ad52adb9a7ef9e1ff.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_6306ff46d0032d2541caf3af9d9d08b9.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_6718a0af16ee9da80a94425b187a63b3.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_8fa21fcdbb35e59c52bf7f28baccd9ac.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_6f7b7a2dafad87d5f66b71b809d16808.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_e501d923e49d35849ceb258ae6bd6350.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_de8ae1c00a13659c5b03deb5e14c4da9.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_aef3fffc871b3c8b88dc43633787262d.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_0ff8e67eb01d0528b32457ef3946dd9a.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_2f8777ed7d3bef7a5707a7926b2ceb7c.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_77f19c40550d9dacf7fd90131a87b290.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_67c29dd530666b8ce000ef687669540d.json for SISTEMAS_UFFcorrosion-v4output ...
# Converting P74_9c7ed35cecde7fdd8a081cfdd582b609.json for SISTEMAS_UFFcorrosion-v4output ...
